# %% [markdown]
# <a href="https://colab.research.google.com/github/CharishmaRankireddy/fmml/blob/main/Copy_of_FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-27 14:20:40--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   212MB/s    in 0.3s
#
# 2024-03-27 14:20:40 (212 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 7551   1802.03203v1  We propose an extension of the canonical polya...  stat
# 22439  1607.01369v3  Given a graph in which a few vertices are deem...  stat
# 20719  1611.04146v2  In this paper, we propose commonsense knowledg...    cs
# 10865  1503.01916v1  Approximate Bayesian computation (ABC) is a po...  stat
# 1730    1411.2674v3  We present the Bayesian Echo Chamber, a new Ba...  stat
# ...             ...                                                ...   ...
# 21502   0709.2936v1  This thesis responds to the challenges of usin...  stat
# 20766  1701.07657v1  With the purpose of modeling, specifying and r...    cs
# 2233   1709.08201v1  Transfer learning significantly accelerates th...    cs
# 2779   1711.09268v3  We present a general-purpose method to train M...  stat
# 18917   1301.2290v1  We present probabilistic logic programming und...    cs
#
#                                                    title  year  \
# 7551     Curve Registered Coupled Low Rank Factorization  2018
# 22439  On the Consistency of the Likelihood Maximizat...  2016
# 20719  Commonsense Knowledge Enhanced Embeddings for ...  2016
# 10865                                    Hamiltonian ABC  2015
# 1730   The Bayesian Echo Chamber: Modeling Social Inf...  2014
# ...                                                  ...   ...
# 21502  Bayesian Classification and Regression with Hi...  2007
# 20766                       Logic Programming Petri Nets  2017
# 2233   An Optimal Online Method of Selecting Source P...  2017
# 2779   Generalizing Hamiltonian Monte Carlo with Neur...  2017
# 18917  Probabilistic Logic Programming under Inherita...  2013
#
#                                                 keywords
# 7551   [extension, canonical, constrained, components...
# 22439  [interesting, nomination, remaining, nominatio...
# 20719  [commonsense, knowledge, embeddings, disambigu...
# 10865  [approximate, computation, framework, performi...
# 1730   [generative, interaction, evolution, discovers...
# ...                                                  ...
# 21502  [challenges, thousands, regression, classifica...
# 20766  [specifying, reasoning, integrated, procedural...
# 2233   [significantly, accelerates, reinforcement, ex...
# 2779   [parameterized, distribution, generalizes, ham...
# 18917  [probabilistic, programming, inheritance, over...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 7551     [extension, canonical, constrained, components...
# 22439    [interesting, nomination, remaining, nominatio...
# 20719    [commonsense, knowledge, embeddings, disambigu...
# 10865    [approximate, computation, framework, performi...
# 1730     [generative, interaction, evolution, discovers...
#                                ...
# 23600    [reconstruction, measurements, importance, eng...
# 36089    [potential, investigated, frequency, coefficie...
# 25739    [recognition, predicting, instances, informati...
# 31334    [denoising, prediction, underlying, simplified...
# 24608    [introduces, localization, leverages, convolut...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8749 words.
# Out of those 4576 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5e3f3961-28b5-4a32-a0e1-82c41d0b7ca3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e3f3961-28b5-4a32-a0e1-82c41d0b7ca3")) {                    Plotly.newPlot(                        "5e3f3961-28b5-4a32-a0e1-82c41d0b7ca3",                        [{"x":["comparing","algorithm","constrained","literature","simulation","registered","canonical","components","extension","parametrized","factorization","decomposition","registration","asymptotically","maximization","theoretical","stochastic","consistency","nomination","estimation","incorporate","effectiveness","restricted","including","empirical","remaining","introduce","interesting","classifier","consistent","performance","additionally","likelihood","approaches","concentration","parameters","disambiguation","therefore","embeddings","linguistic","framework","coreference","knowledge","achieving","unsupervised","traditional","challenge","effective","investigate","extraction","conceptnet","resolution","utilization","commonsense","conducted","information","experiments","computation","relatively","parameter","gradients","simulations","hamiltonian","performing","inference","algorithms","effectively","demonstrate","difficulty","approximate","efficiently","comparably","estimates","incorporating","dimensional","interaction","accommodation","demonstrating","evidenced","generative","inferring","transcripts","evolution","discovers","arguments","relationships","multivariate","uncovering","influence","capabilities","primarily","discussions","committee","standalone","available","evaluation","contribute","standardizing","application","predictions","segmentation","successfully","competition","evaluates","visualizing","providing","challenging","manuscripts","following","industrial","irregular","inevitable","computational","metaheuristics","probability","naturally","independent","functions","different","interpretation","variables","acceptable","implications","conventional","optimization","expensive","structure","structures","flexibility","covariance","architectures","exploiting","containing","specifically","leverages","objective","classification","benchmarks","processes","variational","efficient","procedure","parametric","inductive","generalizes","interpolation","classical","minimization","prediction","exponential","structured","complexity","calibration","optimized","carefully","formalize","surrogate","guarantees","consequence","construct","calibrated","intuition","unlabeled","accompanied","supervised","regularized","prototypical","improvements","explosively","predictors","conditional","distribution","investigated","distributions","dimension","asymptotic","penalized","evaluated","properties","regression","regressions","estimated","important","estimators","polynomial","misspecified","propensity","selection","treatment","misspecification","depression","dimensionality","feedforward","satisfies","coefficients","nonlinear","outperformance","comparisons","modification","characterizing"],"y":[63,764,68,121,83,4,17,105,67,6,38,82,27,14,22,148,132,62,0,215,65,228,47,265,135,16,318,77,161,83,859,75,56,440,10,250,12,137,84,61,538,8,373,74,139,174,141,244,145,131,3,134,19,9,86,689,593,137,68,149,34,46,3,77,185,590,134,572,55,94,170,7,61,65,202,78,1,31,3,122,29,1,61,6,19,53,19,2,64,41,24,7,0,3,318,263,31,2,263,74,217,82,30,15,9,95,295,3,74,20,7,4,268,3,171,58,127,190,762,63,114,14,27,104,310,54,330,132,33,25,115,78,60,170,38,166,517,92,93,56,390,114,39,18,27,14,99,72,254,42,89,248,18,53,51,13,14,72,19,94,10,10,44,7,191,49,5,114,1,17,102,214,51,108,71,20,6,138,219,135,1,72,371,13,63,0,1,167,38,2,3,52,10,20,37,57,3,31,25,13],"type":"bar"},{"x":["comparing","algorithm","constrained","literature","simulation", ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4576,), (4576, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7841666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Multi</span> <span style=''>layer</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Visualization</span> <span style=''>for</span> <span style=''>Medical</span> <span style=''>Mixed</span> <span style=''>Reality</span> <br/><br/><span style=''>Medical</span> <span style=''>Mixed</span> <span style=''>Reality</span> <span style=''>helps</span> <span style=''>surgeons</span> <span style=''>to</span> <span style=''>contextualize</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>intraoperative</span> <span style=''>data</span> <span style=''>with</span> <span style=''>video</span> <span style=''>of</span> <span style=''>the</span> <span style=''>surgical</span> <span style=''>scene</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonetheless</span> <span style=''>the</span> <span style=''>surgical</span> <span style=''>scene</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.4736842105263158);'>anatomical</span> <span style=''>target</span> <span style=''>are</span> <span style=''>often</span> <span style=''>occluded</span> <span style=''>by</span> <span style=''>surgical</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>instruments</span> <span style=''>and</span> <span style=''>surgeon</span> <span style=''>hands</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>and</span> <span style=''>to</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.4598825831702544);'>knowledge</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>multi</span> <span style=''>layer</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>visualization</span> <span style=''>in</span> <span style=''>Medical</span> <span style=''>Mixed</span> <span style=''>Reality</span> <span style=''>solution</span> <span style=''>which</span> <span style=''>subtly</span> <span style=''>improves</span> <span style=''>a</span> <span style=''>surgeons</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>visualization</span> <span style=''>by</span> <span style=''>making</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transparent</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>occluding</span> <span style=''>objects</span> <span style=''>As</span> <span style=''>an</span> <span style=''>example</span> <span style=''>scenario</span> <span style=''>we</span> <span style=''>use</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>augmented</span> <span style=''>reality</span> <span style=''>C</span> <span style=''>arm</span> <span style=''>fluoroscope</span> <span style=''>device</span> <span style=''>A</span> <span style=''>video</span> <span style=''>image</span> <span style=''>is</span> <span style=''>created</span> <span style=''>using</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.8666666666666667);'>volumetric</span> <span style=''>based</span> <span style=''>image</span> <span style=''>synthesization</span> <span style='background-color:rgba(0, 255, 0, 0.3036649214659686);'>technique</span> <span style=''>and</span> <span style=''>stereo</span> <span style=''>RGBD</span> <span style=''>cameras</span> <span style=''>mounted</span> <span style=''>on</span> <span style=''>the</span> <span style=''>C</span> <span style=''>arm</span> <span style=''>From</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.46153846153846145);'>synthesized</span> <span style=''>view</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>background</span> <span style=''>which</span> <span style=''>is</span> <span style=''>occluded</span> <span style=''>by</span> <span style=''>the</span> <span style=''>surgical</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>ins ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Taxonomy</span> <span style=''>of</span> <span style=''>Big</span> <span style=''>Data</span> <span style=''>for</span> <span style=''>Optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Predictive</span> <span style=''>Machine</span> <span style=''>Learning</span> <span style=''>and</span> <span style=''>Data</span> <span style=''>Mining</span> <br/><br/><span style=''>Big</span> <span style=''>data</span> <span style=''>comes</span> <span style=''>in</span> <span style=''>various</span> <span style=''>ways</span> <span style=''>types</span> <span style=''>shapes</span> <span style=''>forms</span> <span style=''>and</span> <span style=''>sizes</span> <span style=''>Indeed</span> <span style=''>almost</span> <span style=''>all</span> <span style=''>areas</span> <span style=''>of</span> <span style=''>science</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technology</span> <span style=''>medicine</span> <span style=''>public</span> <span style=''>health</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>economics</span> <span style=''>business</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>linguistics</span> <span style=''>and</span> <span style=''>social</span> <span style=''>science</span> <span style=''>are</span> <span style=''>bombarded</span> <span style=''>by</span> <span style=''>ever</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increasing</span> <span style=''>flows</span> <span style=''>of</span> <span style=''>data</span> <span style=''>begging</span> <span style=''>to</span> <span style=''>analyzed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiently</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effectively</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>rough</span> <span style=''>idea</span> <span style=''>of</span> <span style=''>a</span> <span style=''>possible</span> <span style=''>taxonomy</span> <span style=''>of</span> <span style=''>big</span> <span style=''>data</span> <span style=''>along</span> <span style=''>with</span> <span style=''>some</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style=''>commonly</span> <span style=''>used</span> <span style=''>tools</span> <span style=''>for</span> <span style=''>handling</span> <span style=''>each</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>category</span> <span style=''>of</span> <span style=''>bigness</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style=''>p</span> <span style=''>of</span> <span style=''>the</span> <span style=''>input</span> <span style=''>space</span> <span style=''>and</span> <span style=''>the</span> <span style=''>sample</span> <span style=''>size</span> <span style=''>n</span> <span style=''>are</span> <span style=''>usually</span> <span style=''>the</span> <span style=''>main</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>ingredients</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characterization</span> <span style=''>of</span> <span style=''>data</span> <span style=''>bigness</span> <span style=''>The</span> <span style=''>specific</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>used</span> <span style=''>to</span> <span style=''>handle</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>big</span> <span style=''>data</span> <span style=''>set</span> <span style=''>will</sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.4782608695652173);'>Simulated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Annealing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Algorithm</span> <span style=''>for</span> <span style=''>Graph</span> <span style=''>Coloring</span> <br/><br/><span style=''>The</span> <span style=''>goal</span> <span style=''>of</span> <span style=''>this</span> <span style=''>Random</span> <span style=''>Walks</span> <span style=''>project</span> <span style=''>is</span> <span style=''>to</span> <span style=''>code</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.33944954128440374);'>experiment</span> <span style=''>the</span> <span style=''>Markov</span> <span style=''>Chain</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>(MCMC)</span> <span style=''>method</span> <span style=''>for</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>graph</span> <span style=''>coloring</span> <span style=''>In</span> <span style=''>this</span> <span style=''>report</span> <span style=''>we</span> <span style=''>present</span> <span style=''>the</span> <span style=''>plots</span> <span style=''>of</span> <span style=''>cost</span> <span style=''>function</span> <span style=''>(mathbfH)</span> <span style=''>by</span> <span style=''>varying</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>like</span> <span style=''>(mathbfq)</span> <span style=''>(Number</span> <span style=''>of</span> <span style=''>colors</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>in</span> <span style=''>coloring)</span> <span style=''>and</span> <span style=''>(mathbfc)</span> <span style=''>(Average</span> <span style=''>node</span> <span style=''>degree)</span> <span style=''>The</span> <span style=''>results</span> <span style=''>are</span> <span style=''>obtained</span> <span style=''>by</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.4782608695652173);'>simulated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>annealing</span> <span style=''>scheme</span> <span style=''>where</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333335);'>temperature</span> <span style=''>(inverse</span> <span style=''>of</span> <span style=''>(mathbfbeta))</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>in</span> <span style=''>the</span> <span style=''>MCMC</span> <span style=''>is</span> <span style=''>lowered</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>progressively</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Local</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Discriminant</span> <span style=''>Hyperalignment</span> <span style=''>for</span> <span style=''>multi</span> <span style=''>subject</span> <span style=''>fMRI</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alignment</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Multivariate</span> <span style=''>Pattern</span> <span style=''>(MVP)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>can</span> <span style=''>map</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>cognitive</span> <span style=''>states</span> <span style=''>to</span> <span style=''>the</span> <span style=''>brain</span> <span style=''>tasks</span> <span style=''>One</span> <span style=''>of</span> <span style=''>the</span> <span style=''>main</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenges</span> <span style=''>in</span> <span style=''>MVP</span> <span style=''>analysis</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>validating</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generated</span> <span style=''>results</span> <span style=''>across</span> <span style=''>subjects</span> <span style=''>However</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>analyzing</span> <span style=''>multi</span> <span style=''>subject</span> <span style=''>fMRI</span> <span style=''>data</span> <span style=''>requires</span> <span style=''>accurate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alignments</span> <span style=''>between</span> <span style=''>neuronal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>activities</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>subjects</span> <span style=''>which</span> <span style=''>can</span> <span style=''>rapidly</span> <span style=''>increase</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>robustness</span> <span style=''>of</span> <span style=''>the</span> <span style=''>final</span> <span style=''>results</span> <span style=''>Hyperalignment</span> <span style=''>(HA)</span> <span style=''>is</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alignment</span> <span style=''>methods</span> <span style=''>which</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>mathematically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulated</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Canonical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Correlation</span> <span style=''>Analysis</span> <span style=''>(CCA)</span> <span style=''>methods</span> <span style=''>Since</span> <span style=''>HA</span> <span style=''>mostly</span> <span style=''>uses</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style=''>CCA</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>its</span> <span style=''>solution</span> <span style=''>may</span> <span style=''>not</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimized</span> <span style=''>for</span> <s ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.13156966490299823)
# 	challenging (0.10405643738977072)
# 	experimental (0.13932980599647266)
# 	segmentation (0.07654320987654321)
# 	detection (0.11887125220458554)
# 	information (0.24303350970017637)
# 	knowledge (0.13156966490299823)
# 	different (0.2687830687830688)
# 	convolutional (0.13544973544973546)
# 	recognition (0.13756613756613756)
#
# Some Statistics words are:
# 	algorithms (0.3043256997455471)
# 	variables (0.13893129770992366)
# 	theoretical (0.15318066157760815)
# 	estimation (0.17709923664122137)
# 	statistical (0.1628498727735369)
# 	dimensional (0.18371501272264631)
# 	regression (0.17760814249363868)
# 	distribution (0.20712468193384223)
# 	algorithm (0.40661577608142496)
# 	inference (0.21017811704834605)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="23c72987-58f8-467a-83d8-6c4dca289bf9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("23c72987-58f8-467a-83d8-6c4dca289bf9")) {                    Plotly.newPlot(                        "23c72987-58f8-467a-83d8-6c4dca289bf9",                        [{"x":["comparing","algorithm","constrained","literature","simulation","registered","canonical","components","extension","parametrized","factorization","decomposition","registration","asymptotically","maximization","theoretical","stochastic","consistency","nomination","estimation","incorporate","effectiveness","restricted","including","empirical","remaining","introduce","interesting","classifier","consistent","performance","additionally","likelihood","approaches","concentration","parameters","disambiguation","therefore","embeddings","linguistic","framework","coreference","knowledge","achieving","unsupervised","traditional","challenge","effective","investigate","extraction","conceptnet","resolution","utilization","commonsense","conducted","information","experiments","computation","relatively","parameter","gradients","simulations","hamiltonian","performing","inference","algorithms","effectively","demonstrate","difficulty","approximate","efficiently","comparably","estimates","incorporating","dimensional","interaction","accommodation","demonstrating","evidenced","generative","inferring","transcripts","evolution","discovers","arguments","relationships","multivariate","uncovering","influence","capabilities","primarily","discussions","committee","standalone","available","evaluation","contribute","standardizing","application","predictions","segmentation","successfully","competition","evaluates","visualizing","providing","challenging","manuscripts","following","industrial","irregular","inevitable","computational","metaheuristics","probability","naturally","independent","functions","different","interpretation","variables","acceptable","implications","conventional","optimization","expensive","structure","structures","flexibility","covariance","architectures","exploiting","containing","specifically","leverages","objective","classification","benchmarks","processes","variational","efficient","procedure","parametric","inductive","generalizes","interpolation","classical","minimization","prediction","exponential","structured","complexity","calibration","optimized","carefully","formalize","surrogate","guarantees","consequence","construct","calibrated","intuition","unlabeled","accompanied","supervised","regularized","prototypical","improvements","explosively","predictors","conditional","distribution","investigated","distributions","dimension","asymptotic","penalized","evaluated","properties","regression","regressions","estimated","important","estimators","polynomial","misspecified","propensity","selection","treatment","misspecification","depression","dimensionality","feedforward","satisfies","coefficients","nonlinear","outperformance","comparisons","modification","characterizing","indicates","hyperspectral","especially","coherency","experimental","principles","furthermore","respective","advantages","regarding","architecture","classifiers","appropriate","reduction","generalization","introduction","ubiquitous","reproducing","statistical","meanwhile","reinforcement","probabilistic","distributional","suggestions","discussion","discovery","comprehensive","directions","graphical","initially","applications","embedding","associated","environment","operating","transform","comparison","characteristic","technique","corrupted","capturing","decomposed","calculated","identification","frequency","recognition","interestingly","assumption","robustness","distinguishable","logarithmic","considered","predicting", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0371135273036507e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7425
